# %%
import geopandas as gpd
import numpy as np
import rasterio
from rasterio.mask import mask
from rasterio.warp import reproject, Resampling
from shapely.geometry import box
from shapely.ops import unary_union
import pandas as pd

# %%
# Inputs
# Pick ONE landform layer:
#landform_gdf = gpd.read_file("teton_outline_final.shp")                    # glaciers
landform_gdf = gpd.read_file("Snow_field_threshold_w_lidar_difference.shp")  # snowfields
#landform_gdf = gpd.read_file("grte_updated_RGI_2025_Project.shp")            # rock glaciers

slope_fp = "Teton_slope_2022_reprojected.tif"   # degrees
dhdt_fp  = "local_hyps_1967_2014_elev_rate.tif"                # dh/dt map used for uncertainty. use USGS_2014_2022_lidar_dhdt_reprojected.tif for 2014-2022 uncertainity

# %%
# Parameters
L_m = 500.0               # decorrelation length (m) for Rolstad scaling
outer_buffer_m = 1000.0   # stable zone buffer radius
exclude_buffer_m = 10.0   # exclusion ring around landforms to avoid edges
slope_thresh_deg = 30.0   # "stable" pixels have slope < this threshold
min_stable_px = 50        # require at least N stable pixels

print("CRS of shapefile (original):", landform_gdf.crs)
# Out:
# CRS of shapefile (original): COMPD_CS["NAD83(2011) / UTM zone 12N + NAVD88 height",PROJCS["NAD83(2011) / UTM zone 12N",GEOGCS["NAD83(2011)",DATUM["NAD83_National_Spatial_Reference_System_2011",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","1116"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","6318"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","6341"]],VERT_CS["NAVD88 height",VERT_DATUM["North American Vertical Datum 1988",2005,AUTHORITY["EPSG","5103"]],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Gravity-related height",UP],AUTHORITY["EPSG","5703"]]]

# %%
records = []

with rasterio.open(slope_fp) as slope_src, rasterio.open(dhdt_fp) as dhdt_src:
    print("CRS of slope raster:", slope_src.crs)
    print("CRS of dh/dt raster:", dhdt_src.crs)

    # Reproject polygons to dh/dt CRS for buffering and intersections
    if landform_gdf.crs != dhdt_src.crs:
        landform_gdf = landform_gdf.to_crs(dhdt_src.crs)

    # Build the 10 m exclusion union *after* reprojecting to dh/dt CRS
    combined_10m_buffers = unary_union(landform_gdf.buffer(exclude_buffer_m).geometry)

    raster_bounds_polygon = box(*dhdt_src.bounds)

    for idx, row in landform_gdf.iterrows():
        geom = row.geometry
        if geom is None or not geom.is_valid:
            continue
        if not geom.intersects(raster_bounds_polygon):
            continue

        try:
            #Stable zone in dh/dt CRS: 1 km buffer minus 10 m exclusion, clipped to raster bounds
            buf_outer = geom.buffer(outer_buffer_m)
            stable_zone = buf_outer.difference(combined_10m_buffers).intersection(raster_bounds_polygon)
            if stable_zone.is_empty:
                print(f"landform {idx}: empty stable zone")
                continue

            #Mask dh/dt within stable zone (in dh/dt CRS)
            dhdt_img, dhdt_tx = mask(dhdt_src, [stable_zone], crop=True, filled=True, nodata=np.nan)
            dhdt_arr = dhdt_img[0]

            #Mask slope within stable zone: reproject polygon to slope CRS, crop slope there
            stable_zone_slope_crs = gpd.GeoSeries([stable_zone], crs=dhdt_src.crs).to_crs(slope_src.crs).iloc[0]
            slope_img, slope_tx = mask(slope_src, [stable_zone_slope_crs], crop=True, filled=True, nodata=np.nan)

            #Reproject slope subset onto the dh/dt subset grid so shapes match
            slope_on_dhdt = np.full(dhdt_arr.shape, np.nan, dtype=np.float32)
            reproject(
                source=slope_img[0],
                destination=slope_on_dhdt,
                src_transform=slope_tx,
                src_crs=slope_src.crs,
                dst_transform=dhdt_tx,
                dst_crs=dhdt_src.crs,
                resampling=Resampling.bilinear
            )

            #Stable mask on dh/dt grid: slope < threshold
            stable_mask = np.isfinite(slope_on_dhdt) & (slope_on_dhdt < slope_thresh_deg)

            # Apply mask to dh/dt and drop NaNs
            dhdt_vals = dhdt_arr[stable_mask]
            dhdt_vals = dhdt_vals[np.isfinite(dhdt_vals)]
            n_stable = dhdt_vals.size
            if n_stable < min_stable_px:
                print(f"landform {idx}: too few stable pixels ({n_stable})")
                continue

            #Stats on stable pixels
            med = float(np.nanmedian(dhdt_vals))
            nmad = float(1.4826 * np.nanmedian(np.abs(dhdt_vals - med)))   # report (robust)
            std_dev = float(np.nanstd(dhdt_vals))                           # base random for Rolstad
            bias = float(np.nanmean(dhdt_vals))                             # systematic (should be ~0)

            #Area A for Rolstad scaling (m²). Prefer attribute if present, else geometry area
            shape_area_attr = None
            for key in ("Shape_Area", "Shape_area", "shape_area", "Area", "AREA"):
                if key in row and pd.notnull(row[key]):
                    try:
                        shape_area_attr = float(row[key])
                    except Exception:
                        shape_area_attr = None
                    break
            A = shape_area_attr if shape_area_attr is not None else float(geom.area)
            if A <= 0:
                print(f"landform {idx}: non-positive area")
                continue

            #Rolstad scaling of STD
            piL2 = np.pi * (L_m ** 2)
            scale = float(np.sqrt(piL2 / A)) if A >= piL2 else 1.0
            sigma_random_scaled = std_dev * scale

            #RMSE using scaled STD + bias (final σΔh)
            rmse = float(np.sqrt(sigma_random_scaled**2 + bias**2))

            # (optional): median of cropped dh/dt subset
            median_elev_dhdt = float(np.nanmedian(dhdt_arr))

            #Save record
            records.append({
                "landform_idx": idx,
                "n_stable_px": int(n_stable),
                "NMAD": nmad,                           # report
                "STD": std_dev,                         # reference
                "bias_mean": bias,                      # systematic
                "scale_factor": scale,                  # Rolstad
                "scaled_sigma_random": sigma_random_scaled,
                "RMSE_sigma_dh": rmse,                  # final σΔh
                "area_m2": A,
                "area_km2": A / 1e6,
                "piL2_km2": piL2 / 1e6,
                "median_elev_dhdt": median_elev_dhdt
            })

            print(
                f"landform {idx}: , NMAD={nmad:.4f}, STD={std_dev:.4f}, "
                f" scale={scale:.4f}, rand_scaled={sigma_random_scaled:.4f}, "
                f"RMSE={rmse:.4f}"
            )

        except Exception as e:
            print(f"Error processing landform {idx}: {e}")
            continue
# Out:
# CRS of slope raster: EPSG:6341
# CRS of dh/dt raster: EPSG:6341
# landform 0: , NMAD=0.0188, STD=0.0253,  scale=1.0000, rand_scaled=0.0253, RMSE=0.0285
# landform 1: , NMAD=0.0252, STD=0.0270,  scale=1.0000, rand_scaled=0.0270, RMSE=0.0343
# landform 2: , NMAD=0.0208, STD=0.0243,  scale=1.0000, rand_scaled=0.0243, RMSE=0.0347
# landform 3: , NMAD=0.0482, STD=0.0504,  scale=1.0000, rand_scaled=0.0504, RMSE=0.0664
# landform 4: , NMAD=0.0386, STD=0.1003,  scale=1.0000, rand_scaled=0.1003, RMSE=0.1137
# landform 5: , NMAD=0.0388, STD=0.0815,  scale=1.0000, rand_scaled=0.0815, RMSE=0.0959
# landform 6: , NMAD=0.0377, STD=0.1060,  scale=1.0000, rand_scaled=0.1060, RMSE=0.1184
# landform 7: , NMAD=0.0430, STD=0.0697,  scale=1.0000, rand_scaled=0.0697, RMSE=0.0710
# landform 8: , NMAD=0.0794, STD=0.0879,  scale=1.0000, rand_scaled=0.0879, RMSE=0.0920
# landform 9: , NMAD=0.0000, STD=0.0000,  scale=1.0000, rand_scaled=0.0000, RMSE=0.0000
# landform 10: , NMAD=0.0916, STD=0.0867,  scale=1.0000, rand_scaled=0.0867, RMSE=0.0869
# landform 11: , NMAD=0.0683, STD=0.0748,  scale=1.0000, rand_scaled=0.0748, RMSE=0.0765
# landform 12: , NMAD=0.0559, STD=0.0599,  scale=1.0000, rand_scaled=0.0599, RMSE=0.0756
# landform 13: , NMAD=0.0590, STD=0.0563,  scale=1.0000, rand_scaled=0.0563, RMSE=0.0760
# landform 14: , NMAD=0.0653, STD=0.0592,  scale=1.0000, rand_scaled=0.0592, RMSE=0.0823
# landform 15: , NMAD=0.0649, STD=0.0594,  scale=1.0000, rand_scaled=0.0594, RMSE=0.0848
# landform 16: , NMAD=0.0191, STD=0.0893,  scale=1.0000, rand_scaled=0.0893, RMSE=0.0923
# landform 17: , NMAD=0.0701, STD=0.0758,  scale=1.0000, rand_scaled=0.0758, RMSE=0.1108
# landform 18: , NMAD=0.0707, STD=0.0752,  scale=1.0000, rand_scaled=0.0752, RMSE=0.1086
# landform 19: , NMAD=0.0690, STD=0.0771,  scale=1.0000, rand_scaled=0.0771, RMSE=0.1088
# landform 20: , NMAD=0.0219, STD=0.1393,  scale=1.0000, rand_scaled=0.1393, RMSE=0.1471
# landform 21: , NMAD=0.0250, STD=0.1310,  scale=1.0000, rand_scaled=0.1310, RMSE=0.1392
# landform 22: , NMAD=0.0427, STD=0.0430,  scale=1.0000, rand_scaled=0.0430, RMSE=0.0589
# landform 23: , NMAD=0.0442, STD=0.0452,  scale=1.0000, rand_scaled=0.0452, RMSE=0.0626
# landform 24: , NMAD=0.0421, STD=0.0486,  scale=1.0000, rand_scaled=0.0486, RMSE=0.0683
# landform 25: , NMAD=0.0372, STD=0.0463,  scale=1.0000, rand_scaled=0.0463, RMSE=0.0668
# landform 26: , NMAD=0.0365, STD=0.0660,  scale=1.0000, rand_scaled=0.0660, RMSE=0.0822
# landform 27: , NMAD=0.0336, STD=0.1128,  scale=1.0000, rand_scaled=0.1128, RMSE=0.1258
# landform 28: , NMAD=0.0334, STD=0.1096,  scale=1.0000, rand_scaled=0.1096, RMSE=0.1227
# landform 29: , NMAD=0.0276, STD=0.0372,  scale=1.0000, rand_scaled=0.0372, RMSE=0.0452
# landform 30: , NMAD=0.0278, STD=0.0371,  scale=1.0000, rand_scaled=0.0371, RMSE=0.0444
# landform 31: , NMAD=0.0483, STD=0.0657,  scale=1.0000, rand_scaled=0.0657, RMSE=0.0743
# landform 32: , NMAD=0.0449, STD=0.0604,  scale=1.0000, rand_scaled=0.0604, RMSE=0.0664
# landform 33: , NMAD=0.0475, STD=0.0563,  scale=1.0000, rand_scaled=0.0563, RMSE=0.0622
# landform 34: , NMAD=0.0181, STD=0.0260,  scale=1.0000, rand_scaled=0.0260, RMSE=0.0291
# landform 35: , NMAD=0.0180, STD=0.0252,  scale=1.0000, rand_scaled=0.0252, RMSE=0.0283
# landform 36: , NMAD=0.0214, STD=0.0271,  scale=1.0000, rand_scaled=0.0271, RMSE=0.0311
# landform 37: , NMAD=0.0204, STD=0.0269,  scale=1.0000, rand_scaled=0.0269, RMSE=0.0312
# landform 38: , NMAD=0.0403, STD=0.0678,  scale=1.0000, rand_scaled=0.0678, RMSE=0.0702
# landform 39: , NMAD=0.0362, STD=0.0683,  scale=1.0000, rand_scaled=0.0683, RMSE=0.0703
# landform 40: , NMAD=0.0393, STD=0.0468,  scale=1.0000, rand_scaled=0.0468, RMSE=0.0641
# landform 41: , NMAD=0.0503, STD=0.0616,  scale=1.0000, rand_scaled=0.0616, RMSE=0.0657
# landform 42: , NMAD=0.0579, STD=0.0691,  scale=1.0000, rand_scaled=0.0691, RMSE=0.0726
# landform 43: , NMAD=0.0608, STD=0.0711,  scale=1.0000, rand_scaled=0.0711, RMSE=0.0712
# landform 44: , NMAD=0.0197, STD=0.0284,  scale=1.0000, rand_scaled=0.0284, RMSE=0.0430
# landform 45: , NMAD=0.1211, STD=0.0920,  scale=1.0000, rand_scaled=0.0920, RMSE=0.1307
# landform 46: , NMAD=0.0230, STD=0.0287,  scale=1.0000, rand_scaled=0.0287, RMSE=0.0426
# landform 47: , NMAD=0.0829, STD=0.0773,  scale=1.0000, rand_scaled=0.0773, RMSE=0.1050
# landform 48: , NMAD=0.0565, STD=0.0688,  scale=1.0000, rand_scaled=0.0688, RMSE=0.0902
# landform 49: , NMAD=0.0535, STD=0.0650,  scale=1.0000, rand_scaled=0.0650, RMSE=0.0795
# landform 50: , NMAD=0.0205, STD=0.0279,  scale=1.0000, rand_scaled=0.0279, RMSE=0.0470
# landform 51: , NMAD=0.0250, STD=0.0307,  scale=1.0000, rand_scaled=0.0307, RMSE=0.0425
# landform 52: , NMAD=0.0246, STD=0.0298,  scale=1.0000, rand_scaled=0.0298, RMSE=0.0439
# landform 53: , NMAD=0.0247, STD=0.0397,  scale=1.0000, rand_scaled=0.0397, RMSE=0.0398
# landform 54: , NMAD=0.0284, STD=0.0298,  scale=1.0000, rand_scaled=0.0298, RMSE=0.0390
# landform 55: , NMAD=0.0242, STD=0.0269,  scale=1.0000, rand_scaled=0.0269, RMSE=0.0439
# landform 56: , NMAD=0.0233, STD=0.0265,  scale=1.0000, rand_scaled=0.0265, RMSE=0.0320
# landform 57: , NMAD=0.0199, STD=0.0243,  scale=1.0000, rand_scaled=0.0243, RMSE=0.0344
# landform 58: , NMAD=0.0221, STD=0.0270,  scale=1.0000, rand_scaled=0.0270, RMSE=0.0356
# landform 59: , NMAD=0.0258, STD=0.0286,  scale=1.0000, rand_scaled=0.0286, RMSE=0.0379
# landform 60: , NMAD=0.0262, STD=0.0299,  scale=1.0000, rand_scaled=0.0299, RMSE=0.0346
# landform 61: , NMAD=0.0268, STD=0.0343,  scale=1.0000, rand_scaled=0.0343, RMSE=0.0369
# landform 62: , NMAD=0.0272, STD=0.0360,  scale=1.0000, rand_scaled=0.0360, RMSE=0.0389
# landform 63: , NMAD=0.0330, STD=0.0407,  scale=1.0000, rand_scaled=0.0407, RMSE=0.0466
# landform 64: , NMAD=0.0340, STD=0.0412,  scale=1.0000, rand_scaled=0.0412, RMSE=0.0479
# landform 65: , NMAD=0.0215, STD=0.0313,  scale=1.0000, rand_scaled=0.0313, RMSE=0.0336
# landform 66: , NMAD=0.0359, STD=0.0453,  scale=1.0000, rand_scaled=0.0453, RMSE=0.0454
# landform 67: , NMAD=0.0371, STD=0.0455,  scale=1.0000, rand_scaled=0.0455, RMSE=0.0456
# landform 68: , NMAD=0.0356, STD=0.0447,  scale=1.0000, rand_scaled=0.0447, RMSE=0.0452
# landform 69: , NMAD=0.0295, STD=0.0346,  scale=1.0000, rand_scaled=0.0346, RMSE=0.0372
# landform 70: , NMAD=0.0299, STD=0.0623,  scale=1.0000, rand_scaled=0.0623, RMSE=0.0628
# landform 71: , NMAD=0.0505, STD=0.0888,  scale=1.0000, rand_scaled=0.0888, RMSE=0.0931
# landform 72: , NMAD=0.0528, STD=0.0872,  scale=1.0000, rand_scaled=0.0872, RMSE=0.0943
# landform 73: , NMAD=0.0495, STD=0.0811,  scale=1.0000, rand_scaled=0.0811, RMSE=0.0884
# landform 74: , NMAD=0.0528, STD=0.0877,  scale=1.0000, rand_scaled=0.0877, RMSE=0.0944
# landform 75: , NMAD=0.0587, STD=0.0919,  scale=1.0000, rand_scaled=0.0919, RMSE=0.1022
# landform 76: , NMAD=0.0513, STD=0.0874,  scale=1.0000, rand_scaled=0.0874, RMSE=0.0921
# landform 77: , NMAD=0.0292, STD=0.0301,  scale=1.0000, rand_scaled=0.0301, RMSE=0.0376
# landform 78: , NMAD=0.0287, STD=0.0307,  scale=1.0000, rand_scaled=0.0307, RMSE=0.0399
# landform 79: , NMAD=0.0334, STD=0.0474,  scale=1.0000, rand_scaled=0.0474, RMSE=0.0489
# landform 80: , NMAD=0.0263, STD=0.0469,  scale=1.0000, rand_scaled=0.0469, RMSE=0.0511
# landform 81: , NMAD=0.0246, STD=0.0401,  scale=1.0000, rand_scaled=0.0401, RMSE=0.0415
# landform 82: , NMAD=0.0405, STD=0.0470,  scale=1.0000, rand_scaled=0.0470, RMSE=0.0473
# landform 83: , NMAD=0.0416, STD=0.0483,  scale=1.0000, rand_scaled=0.0483, RMSE=0.0493
# landform 84: , NMAD=0.0213, STD=0.0387,  scale=1.0000, rand_scaled=0.0387, RMSE=0.0397
# landform 85: , NMAD=0.0375, STD=0.0454,  scale=1.0000, rand_scaled=0.0454, RMSE=0.0484
# landform 86: , NMAD=0.0242, STD=0.0323,  scale=1.0000, rand_scaled=0.0323, RMSE=0.0367
# landform 87: , NMAD=0.0257, STD=0.0324,  scale=1.0000, rand_scaled=0.0324, RMSE=0.0324
# landform 88: , NMAD=0.0381, STD=0.0432,  scale=1.0000, rand_scaled=0.0432, RMSE=0.0439
# landform 89: , NMAD=0.0267, STD=0.0336,  scale=1.0000, rand_scaled=0.0336, RMSE=0.0385
# landform 90: , NMAD=0.0308, STD=0.0364,  scale=1.0000, rand_scaled=0.0364, RMSE=0.0369
# landform 91: , NMAD=0.0485, STD=0.0463,  scale=1.0000, rand_scaled=0.0463, RMSE=0.0537
# landform 92: , NMAD=0.0438, STD=0.0390,  scale=1.0000, rand_scaled=0.0390, RMSE=0.0492
# landform 93: , NMAD=0.0431, STD=0.0373,  scale=1.0000, rand_scaled=0.0373, RMSE=0.0486
# landform 94: , NMAD=0.0398, STD=0.0421,  scale=1.0000, rand_scaled=0.0421, RMSE=0.0486
# landform 95: , NMAD=0.0296, STD=0.0429,  scale=1.0000, rand_scaled=0.0429, RMSE=0.0475
# landform 96: , NMAD=0.0284, STD=0.0425,  scale=1.0000, rand_scaled=0.0425, RMSE=0.0453
# landform 97: , NMAD=0.0000, STD=0.0398,  scale=1.0000, rand_scaled=0.0398, RMSE=0.0400
# landform 98: , NMAD=0.0000, STD=0.0237,  scale=1.0000, rand_scaled=0.0237, RMSE=0.0241
# landform 99: , NMAD=0.0000, STD=0.0238,  scale=1.0000, rand_scaled=0.0238, RMSE=0.0245
# landform 100: , NMAD=0.0000, STD=0.0072,  scale=1.0000, rand_scaled=0.0072, RMSE=0.0072
# landform 101: , NMAD=0.0000, STD=0.0000,  scale=1.0000, rand_scaled=0.0000, RMSE=0.0000
# landform 102: , NMAD=0.0246, STD=0.0271,  scale=1.0000, rand_scaled=0.0271, RMSE=0.0425
# landform 103: , NMAD=0.0431, STD=0.0804,  scale=1.0000, rand_scaled=0.0804, RMSE=0.0840

# %%
# =============================
# Results table
# =============================
df = pd.DataFrame.from_records(records).sort_values("landform_idx").reset_index(drop=True)
#print("\nSummary:")
print(df)

# Compute and print plain average RMSE across landforms
if not df.empty:
    avg_rmse = df["RMSE_sigma_dh"].mean()
    print(f"\nAverage RMSE across {len(df)} landforms: {avg_rmse:.4f}")
else:
    print("\nNo valid landforms processed, cannot compute average RMSE.")
# Out:
#      landform_idx  n_stable_px      NMAD       STD  bias_mean  scale_factor  \
# 0               0      1572627  0.018760  0.025265  -0.013181           1.0
# 1               1      1384884  0.025168  0.026990  -0.021161           1.0
# 2               2      1394472  0.020832  0.024339  -0.024801           1.0
# 3               3      1815805  0.048187  0.050433  -0.043228           1.0
# 4               4      1965315  0.038584  0.100314  -0.053446           1.0
# ..            ...          ...       ...       ...        ...           ...
# 99             99       836092  0.000000  0.023791   0.005855           1.0
# 100           100      1331648  0.000000  0.007155   0.000539           1.0
# 101           101      1372410  0.000000  0.000000   0.000000           1.0
# 102           102      1856831  0.024552  0.027127  -0.032665           1.0
# 103           103       999135  0.043135  0.080375  -0.024373           1.0
#
#      scaled_sigma_random  RMSE_sigma_dh       area_m2  area_km2  piL2_km2  \
# 0               0.025265       0.028496   2560.096177  0.002560  0.785398
# 1               0.026990       0.034297  13407.955423  0.013408  0.785398
# 2               0.024339       0.034749   1513.334143  0.001513  0.785398
# 3               0.050433       0.066424   2772.040179  0.002772  0.785398
# 4               0.100314       0.113663  10274.633360  0.010275  0.785398
# ..                   ...            ...           ...       ...       ...
# 99              0.023791       0.024500   1109.332151  0.001109  0.785398
# 100             0.007155       0.007175   3220.416702  0.003220  0.785398
# 101             0.000000       0.000000   2169.477318  0.002169  0.785398
# 102             0.027127       0.042460   3018.159376  0.003018  0.785398
# 103             0.080375       0.083989   3842.441797  0.003842  0.785398
#
#      median_elev_dhdt
# 0           -0.016041
# 1           -0.022014
# 2           -0.024424
# 3           -0.040574
# 4           -0.040610
# ..                ...
# 99           0.000000
# 100          0.000000
# 101          0.000000
# 102         -0.029614
# 103          0.000000
#
# [104 rows x 12 columns]
#
# Average RMSE across 104 landforms: 0.0605
